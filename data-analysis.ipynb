# %%
import requests
import pandas as pd
import time
import re
from urllib.parse import parse_qs, urlparse
import sys

def validate_token(token):
    """Validate the GitHub token before proceeding"""
    headers = {"Authorization": f"token {token}"}
    response = requests.get("https://api.github.com/user", headers=headers)
    
    if response.status_code == 401:
        print("Error: Invalid GitHub token. Please check your token and try again.")
        print("Make sure you've replaced 'your_personal_access_token' with an actual token.")
        print("\nTo create a new token:")
        print("1. Go to GitHub.com → Settings → Developer settings → Personal access tokens → Tokens (classic)")
        print("2. Generate new token (classic)")
        print("3. Select at least these scopes: 'public_repo', 'read:user', 'user:email'")
        return False
    elif response.status_code != 200:
        print(f"Error: Unable to validate token. Status code: {response.status_code}")
        print(f"Response: {response.text}")
        return False
    return True

def get_users_in_tokyo(token, min_followers=200):
    base_url = "https://api.github.com/search/users"
    headers = {"Authorization": f"token {token}"}
    params = {
        "q": f"location:tokyo followers:>{min_followers}",
        "per_page": 100,
        "page": 1
    }
    all_users = []
    
    while True:
        try:
            response = requests.get(base_url, headers=headers, params=params)
            
            if response.status_code == 200:
                data = response.json()
                items = data.get('items', [])
                all_users.extend(items)
                
                # Print progress
                print(f"Fetched page {params['page']}, Total users so far: {len(all_users)}")
                total_count = data.get('total_count', 0)
                print(f"Total users available according to GitHub: {total_count}")
                
                # Check if there are more pages
                if 'next' not in response.links or not items:
                    break
                    
                # Extract next page number from the 'next' URL
                next_url = response.links['next']['url']
                parsed_url = urlparse(next_url)
                params['page'] = int(parse_qs(parsed_url.query)['page'][0])
                
                # Handle rate limiting
                remaining = int(response.headers.get('X-RateLimit-Remaining', 0))
                if remaining < 5:
                    reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
                    sleep_time = max(reset_time - time.time(), 0) + 1
                    print(f"Rate limit nearly exceeded. Sleeping for {sleep_time:.0f} seconds...")
                    time.sleep(sleep_time)
                else:
                    time.sleep(2)  # Normal rate limit control
            else:
                print(f"Error fetching users: {response.status_code}")
                print(f"Response: {response.text}")
                if response.status_code == 403:  # Rate limit exceeded
                    reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
                    sleep_time = max(reset_time - time.time(), 0) + 1
                    print(f"Rate limit exceeded. Sleeping for {sleep_time:.0f} seconds...")
                    time.sleep(sleep_time)
                    continue
                break
                
        except requests.exceptions.RequestException as e:
            print(f"Network error occurred: {e}")
            time.sleep(5)  # Wait before retrying
            continue
        except Exception as e:
            print(f"Unexpected error occurred: {e}")
            break

    print(f"Total users found: {len(all_users)}")
    return all_users

def get_user_details(username, token):
    url = f"https://api.github.com/users/{username}"
    headers = {"Authorization": f"token {token}"}
    max_retries = 3
    retry_count = 0
    
    while retry_count < max_retries:
        try:
            response = requests.get(url, headers=headers)
            if response.status_code == 200:
                return response.json()
            elif response.status_code == 403:  # Rate limit exceeded
                reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
                sleep_time = max(reset_time - time.time(), 0) + 1
                print(f"Rate limit exceeded. Sleeping for {sleep_time:.0f} seconds...")
                time.sleep(sleep_time)
                retry_count += 1
            else:
                print(f"Error fetching user details for {username}: {response.status_code}")
                print(f"Response: {response.text}")
                return None
        except requests.exceptions.RequestException as e:
            print(f"Network error occurred while fetching user {username}: {e}")
            time.sleep(5)
            retry_count += 1
    return None

def get_user_repos(username, token, max_repos=500):
    headers = {"Authorization": f"token {token}"}
    base_url = f"https://api.github.com/users/{username}/repos"
    params = {"per_page": 100, "sort": "updated"}
    repos = []
    page = 1
    
    while len(repos) < max_repos:
        try:
            params['page'] = page
            response = requests.get(base_url, headers=headers, params=params)
            
            if response.status_code == 200:
                page_repos = response.json()
                if not page_repos:  # No more repos
                    break
                repos.extend(page_repos)
                page += 1
                
                remaining = int(response.headers.get('X-RateLimit-Remaining', 0))
                if remaining < 5:
                    reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
                    sleep_time = max(reset_time - time.time(), 0) + 1
                    print(f"Rate limit nearly exceeded. Sleeping for {sleep_time:.0f} seconds...")
                    time.sleep(sleep_time)
                else:
                    time.sleep(1)
            elif response.status_code == 403:  # Rate limit exceeded
                reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
                sleep_time = max(reset_time - time.time(), 0) + 1
                print(f"Rate limit exceeded. Sleeping for {sleep_time:.0f} seconds...")
                time.sleep(sleep_time)
                continue
            else:
                print(f"Error fetching repos for {username}: {response.status_code}")
                print(f"Response: {response.text}")
                break
        except requests.exceptions.RequestException as e:
            print(f"Network error occurred while fetching repos for {username}: {e}")
            time.sleep(5)
            continue
        except Exception as e:
            print(f"Unexpected error occurred while fetching repos: {e}")
            break

    return repos[:max_repos]

def clean_company_name(company):
    """Clean company name"""
    if company:
        company = company.lstrip('@').strip().upper()
        company = re.sub(r"\s+", " ", company)
    return company if company else ""

def clean_name(name):
    """Clean name"""
    if name:
        name = re.sub(r"\s+", " ", name).strip()
    return name if name else ""

def clean_bio(bio):
    """Clean bio"""
    if bio:
        bio = re.sub(r"\s+", " ", bio).strip()
    return bio if bio else ""

def clean_email(email):
    """Clean email"""
    return email.strip() if email else ""

def safe_get_license_name(repo):
    """Safely get license name from repository data"""
    try:
        license_data = repo.get('license')
        if isinstance(license_data, dict):
            return license_data.get('name', '')
        return ''
    except:
        return ''

def main():
    # Get GitHub token
    GITHUB_TOKEN = "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"  # Replace with your actual token
    
    # Validate the token before proceeding
    if not validate_token(GITHUB_TOKEN):
        sys.exit(1)
        
    print("GitHub token validated successfully!")
    
    # Data storage
    users_data = []
    repos_data = []

    try:
        # Get users from Tokyo with over 200 followers
        users = get_users_in_tokyo(GITHUB_TOKEN)
        if not users:
            print("No users found. Exiting...")
            sys.exit(1)
            
        print(f"Processing {len(users)} users...")

        # Process each user
        for i, user in enumerate(users, 1):
            username = user['login']
            print(f"\nProcessing user {i}/{len(users)}: {username}")
            
            try:
                # Get detailed user info
                user_details = get_user_details(username, GITHUB_TOKEN)
                if user_details:
                    # Clean and process user data
                    user_data = {
                        "login": user_details.get("login", ""),
                        "name": clean_name(user_details.get("name", "")),
                        "company": clean_company_name(user_details.get("company", "")),
                        "location": user_details.get("location", ""),
                        "email": clean_email(user_details.get("email", "")),
                        "hireable": str(user_details.get("hireable", "")),
                        "bio": clean_bio(user_details.get("bio", "")),
                        "public_repos": user_details.get("public_repos", 0),
                        "followers": user_details.get("followers", 0),
                        "following": user_details.get("following", 0),
                        "created_at": user_details.get("created_at", "")
                    }
                    users_data.append(user_data)
                    
                    # Get repositories for the user
                    print(f"Fetching repositories for {username}")
                    user_repos = get_user_repos(username, GITHUB_TOKEN)
                    for repo in user_repos:
                        try:
                            repo_data = {
                                "login": username,
                                "full_name": repo.get("full_name", ""),
                                "created_at": repo.get("created_at", ""),
                                "stargazers_count": repo.get("stargazers_count", 0),
                                "watchers_count": repo.get("watchers_count", 0),
                                "language": repo.get("language", ""),
                                "has_projects": repo.get("has_projects", False),
                                "has_wiki": repo.get("has_wiki", False),
                                "license_name": safe_get_license_name(repo)
                            }
                            repos_data.append(repo_data)
                        except Exception as e:
                            print(f"Error processing repository data for {username}: {e}")
                            continue
                    
                    print(f"Added {len(user_repos)} repositories for {username}")
            except Exception as e:
                print(f"Error processing user {username}: {e}")
                continue

        # Convert lists to DataFrames
        users_df = pd.DataFrame(users_data)
        repos_df = pd.DataFrame(repos_data)

        # Save to CSV with timestamp
        timestamp = time.strftime("%Y%m%d_%H%M%S")
        users_csv = f"tokyo_users_{timestamp}.csv"
        repos_csv = f"tokyo_repos_{timestamp}.csv"
        
        users_df.to_csv(users_csv, index=False)
        repos_df.to_csv(repos_csv, index=False)

        print(f"\nData saved to {users_csv} and {repos_csv}")
        print(f"Total users processed: {len(users_data)}")
        print(f"Total repositories processed: {len(repos_data)}")

    except Exception as e:
        print(f"An error occurred in the main process: {e}")
        sys.exit(1)

if __name__ == "__main__":
    main()
# Out:
# GitHub token validated successfully!
# Fetched page 1, Total users so far: 100
# Total users available according to GitHub: 542
# Fetched page 2, Total users so far: 200
# Total users available according to GitHub: 542
# Fetched page 3, Total users so far: 300
# Total users available according to GitHub: 542
# Fetched page 4, Total users so far: 400
# Total users available according to GitHub: 542
# Fetched page 5, Total users so far: 500
# Total users available according to GitHub: 542
# Fetched page 6, Total users so far: 542
# Total users available according to GitHub: 542
# Total users found: 542
# Processing 542 users...
#
# Processing user 1/542: dennybritz
# Fetching repositories for dennybritz
# Added 61 repositories for dennybritz
#
# Processing user 2/542: wasabeef
# Fetching repositories for wasabeef
# Added 46 repositories for wasabeef
#
# Processing user 3/542: dai-shi
# Fetching repositories for dai-shi
# Added 128 repositories for dai-shi
#
# Processing user 4/542: rui314
# Fetching repositories for rui314
# Added 44 repositories for rui314
#
# Processing user 5/542: domenic
# Fetching repositories for domenic
# Added 216 repositories for domenic
#
# Processing user 6/542: guo-yu
# Fetching repositories for guo-yu
# Added 209 repositories for guo-yu
#
# Processing user 7/542: hardmaru
# Fetching repositories for hardmaru
# Added 75 repositories for hardmaru
#
# Processing user 8/542: marcan
# Fetching repositories for marcan
# Added 84 repositories for marcan
#
# Processing user 9/542: cpojer
# Fetching repositories for cpojer
# Added 150 repositories for cpojer
#
# Processing user 10/542: kazupon
# Fetching repositories for kazupon
# Added 310 repositories for kazupon
#
# Processing user 11/542: blueimp
# Fetching repositories for blueimp
# Added 35 repositories for blueimp
#
# Processing user 12/542: neuecc
# Fetching repositories for neuecc
# Added 57 repositories for neuecc
#
# Processing user 13/542: shu223
# Fetching repositories for shu223
# Added 76 repositories for shu223
#
# Processing user 14/542: privatenumber
# Fetching repositories for privatenumber
# Added 223 repositories for privatenumber
#
# Processing user 15/542: opengineer
# Fetching repositories for opengineer
# Added 10 repositories for opengineer
#
# Processing user 16/542: asahilina
# Fetching repositories for asahilina
# Added 17 repositories for asahilina
#
# Processing user 17/542: Sen-Takatsuki
# Fetching repositories for Sen-Takatsuki
# Added 12 repositories for Sen-Takatsuki
#
# Processing user 18/542: amatsuda
# Fetching repositories for amatsuda
# Added 218 repositories for amatsuda
#
# Processing user 19/542: kishikawakatsumi
# Fetching repositories for kishikawakatsumi
# Added 163 repositories for kishikawakatsumi
#
# Processing user 20/542: azu
# Fetching repositories for azu
# Added 500 repositories for azu
#
# Processing user 21/542: pilcrowonpaper
# Fetching repositories for pilcrowonpaper
# Added 50 repositories for pilcrowonpaper
#
# Processing user 22/542: wkentaro
# Fetching repositories for wkentaro
# Added 343 repositories for wkentaro
#
# Processing user 23/542: mob-sakai
# Fetching repositories for mob-sakai
# Added 62 repositories for mob-sakai
#
# Processing user 24/542: acgotaku
# Fetching repositories for acgotaku
# Added 47 repositories for acgotaku
#
# Processing user 25/542: mariotaku
# Fetching repositories for mariotaku
# Added 142 repositories for mariotaku
#
# Processing user 26/542: Cysharp
# Fetching repositories for Cysharp
# Added 40 repositories for Cysharp
#
# Processing user 27/542: chrislgarry
# Fetching repositories for chrislgarry
# Added 34 repositories for chrislgarry
#
# Processing user 28/542: hajimehoshi
# Fetching repositories for hajimehoshi
# Added 155 repositories for hajimehoshi
#
# Processing user 29/542: brettwooldridge
# Fetching repositories for brettwooldridge
# Added 91 repositories for brettwooldridge
#
# Processing user 30/542: rhysd
# Fetching repositories for rhysd
# Added 500 repositories for rhysd
#
# Processing user 31/542: yaraki
# Fetching repositories for yaraki
# Added 26 repositories for yaraki
#
# Processing user 32/542: Jannchie
# Fetching repositories for Jannchie
# Added 184 repositories for Jannchie
#
# Processing user 33/542: fukamachi
# Fetching repositories for fukamachi
# Added 176 repositories for fukamachi
#
# Processing user 34/542: nagadomi
# Fetching repositories for nagadomi
# Added 57 repositories for nagadomi
#
# Processing user 35/542: chomado
# Fetching repositories for chomado
# Added 139 repositories for chomado
#
# Processing user 36/542: kazuho
# Fetching repositories for kazuho
# Added 153 repositories for kazuho
#
# Processing user 37/542: ikeay
# Fetching repositories for ikeay
# Added 26 repositories for ikeay
#
# Processing user 38/542: ktoso
# Fetching repositories for ktoso
# Added 416 repositories for ktoso
#
# Processing user 39/542: AkihiroSuda
# Fetching repositories for AkihiroSuda
# Added 299 repositories for AkihiroSuda
#
# Processing user 40/542: hsbt
# Fetching repositories for hsbt
# Added 280 repositories for hsbt
#
# Processing user 41/542: Hironsan
# Fetching repositories for Hironsan
# Added 35 repositories for Hironsan
#
# Processing user 42/542: TimOliver
# Fetching repositories for TimOliver
# Added 142 repositories for TimOliver
#
# Processing user 43/542: mattatz
# Fetching repositories for mattatz
# Added 76 repositories for mattatz
#
# Processing user 44/542: mizchi
# Fetching repositories for mizchi
# Added 411 repositories for mizchi
#
# Processing user 45/542: unhappychoice
# Fetching repositories for unhappychoice
# Added 29 repositories for unhappychoice
#
# Processing user 46/542: Desgard
# Fetching repositories for Desgard
# Added 143 repositories for Desgard
#
# Processing user 47/542: glassesfactory
# Fetching repositories for glassesfactory
# Added 67 repositories for glassesfactory
#
# Processing user 48/542: gkjohnson
# Fetching repositories for gkjohnson
# Added 106 repositories for gkjohnson
#
# Processing user 49/542: twada
# Fetching repositories for twada
# Added 49 repositories for twada
#
# Processing user 50/542: ykob
# Fetching repositories for ykob
# Added 110 repositories for ykob
#
# Processing user 51/542: thagikura
# Fetching repositories for thagikura
# Added 57 repositories for thagikura
#
# Processing user 52/542: naoya
# Fetching repositories for naoya
# Added 135 repositories for naoya
#
# Processing user 53/542: inamiy
# Fetching repositories for inamiy
# Added 155 repositories for inamiy
#
# Processing user 54/542: mono0926
# Fetching repositories for mono0926
# Added 355 repositories for mono0926
#
# Processing user 55/542: baku89
# Fetching repositories for baku89
# Added 103 repositories for baku89
#
# Processing user 56/542: ko1
# Fetching repositories for ko1
# Added 74 repositories for ko1
#
# Processing user 57/542: sureJiang
# Fetching repositories for sureJiang
# Added 7 repositories for sureJiang
#
# Processing user 58/542: Kaixhin
# Fetching repositories for Kaixhin
# Added 42 repositories for Kaixhin
#
# Processing user 59/542: jamesknelson
# Fetching repositories for jamesknelson
# Added 137 repositories for jamesknelson
#
# Processing user 60/542: NicolasDorier
# Fetching repositories for NicolasDorier
# Added 108 repositories for NicolasDorier
#
# Processing user 61/542: yuk7
# Fetching repositories for yuk7
# Added 75 repositories for yuk7
#
# Processing user 62/542: dsh0416
# Fetching repositories for dsh0416
# Added 172 repositories for dsh0416
#
# Processing user 63/542: matchai
# Fetching repositories for matchai
# Added 146 repositories for matchai
#
# Processing user 64/542: line
# Fetching repositories for line
# Added 140 repositories for line
#
# Processing user 65/542: BrambleXu
# Fetching repositories for BrambleXu
# Added 39 repositories for BrambleXu
#
# Processing user 66/542: muukii
# Fetching repositories for muukii
# Added 309 repositories for muukii
#
# Processing user 67/542: xct
# Fetching repositories for xct
# Added 37 repositories for xct
#
# Processing user 68/542: jrjohansson
# Fetching repositories for jrjohansson
# Added 28 repositories for jrjohansson
#
# Processing user 69/542: plouc
# Fetching repositories for plouc
# Added 101 repositories for plouc
#
# Processing user 70/542: kana
# Fetching repositories for kana
# Added 142 repositories for kana
#
# Processing user 71/542: gfx
# Fetching repositories for gfx
# Added 445 repositories for gfx
#
# Processing user 72/542: ra1028
# Fetching repositories for ra1028
# Added 59 repositories for ra1028
#
# Processing user 73/542: tokuhirom
# Fetching repositories for tokuhirom
# Added 500 repositories for tokuhirom
#
# Processing user 74/542: nateberkopec
# Fetching repositories for nateberkopec
# Added 127 repositories for nateberkopec
#
# Processing user 75/542: hiroppy
# Fetching repositories for hiroppy
# Added 262 repositories for hiroppy
#
# Processing user 76/542: sorah
# Fetching repositories for sorah
# Added 357 repositories for sorah
#
# Processing user 77/542: Mikubill
# Fetching repositories for Mikubill
# Added 14 repositories for Mikubill
#
# Processing user 78/542: cambecc
# Fetching repositories for cambecc
# Added 12 repositories for cambecc
#
# Processing user 79/542: syoyo
# Fetching repositories for syoyo
# Added 283 repositories for syoyo
#
# Processing user 80/542: kt3k
# Fetching repositories for kt3k
# Added 500 repositories for kt3k
#
# Processing user 81/542: smorimoto
# Fetching repositories for smorimoto
# Added 342 repositories for smorimoto
#
# Processing user 82/542: lestrrat
# Fetching repositories for lestrrat
# Added 74 repositories for lestrrat
#
# Processing user 83/542: xuwei-k
# Fetching repositories for xuwei-k
# Added 500 repositories for xuwei-k
#
# Processing user 84/542: seratch
# Fetching repositories for seratch
# Added 310 repositories for seratch
#
# Processing user 85/542: SakanaAI
# Fetching repositories for SakanaAI
# Added 6 repositories for SakanaAI
#
# Processing user 86/542: ishkawa
# Fetching repositories for ishkawa
# Added 109 repositories for ishkawa
#
# Processing user 87/542: franciscop
# Fetching repositories for franciscop
# Added 202 repositories for franciscop
#
# Processing user 88/542: vvakame
# Fetching repositories for vvakame
# Added 198 repositories for vvakame
#
# Processing user 89/542: masuidrive
# Fetching repositories for masuidrive
# Added 99 repositories for masuidrive
#
# Processing user 90/542: veryyoung
# Fetching repositories for veryyoung
# Added 19 repositories for veryyoung
#
# Processing user 91/542: making
# Fetching repositories for making
# Added 500 repositories for making
#
# Processing user 92/542: kamipo
# Fetching repositories for kamipo
# Added 100 repositories for kamipo
#
# Processing user 93/542: Phineas
# Fetching repositories for Phineas
# Added 40 repositories for Phineas
#
# Processing user 94/542: marty-suzuki
# Fetching repositories for marty-suzuki
# Added 80 repositories for marty-suzuki
#
# Processing user 95/542: lambdalisue
# Fetching repositories for lambdalisue
# Added 500 repositories for lambdalisue
#
# Processing user 96/542: ryo-ma
# Fetching repositories for ryo-ma
# Added 77 repositories for ryo-ma
#
# Processing user 97/542: syohex
# Fetching repositories for syohex
# Added 500 repositories for syohex
#
# Processing user 98/542: agektmr
# Fetching repositories for agektmr
# Added 80 repositories for agektmr
#
# Processing user 99/542: Saul-Mirone
# Fetching repositories for Saul-Mirone
# Added 13 repositories for Saul-Mirone
#
# Processing user 100/542: wass08
# Fetching repositories for wass08
# Added 141 repositories for wass08
#
# Processing user 101/542: tcnksm
# Fetching repositories for tcnksm
# Added 136 repositories for tcnksm
#
# Processing user 102/542: bytatsu0302
# Fetching repositories for bytatsu0302
# Added 0 repositories for bytatsu0302
#
# Processing user 103/542: shanzi
# Fetching repositories for shanzi
# Added 47 repositories for shanzi
#
# Processing user 104/542: watilde
# Fetching repositories for watilde
# Added 500 repositories for watilde
#
# Processing user 105/542: c-bata
# Fetching repositories for c-bata
# Added 171 repositories for c-bata
#
# Processing user 106/542: potato4d
# Fetching repositories for potato4d
# Added 75 repositories for potato4d
#
# Processing user 107/542: koute
# Fetching repositories for koute
# Added 109 repositories for koute
#
# Processing user 108/542: satoruhiga
# Fetching repositories for satoruhiga
# Added 110 repositories for satoruhiga
#
# Processing user 109/542: sideshowbarker
# Fetching repositories for sideshowbarker
# Added 58 repositories for sideshowbarker
#
# Processing user 110/542: RobertTLange
# Fetching repositories for RobertTLange
# Added 36 repositories for RobertTLange
#
# Processing user 111/542: Jessidhia
# Fetching repositories for Jessidhia
# Added 118 repositories for Jessidhia
#
# Processing user 112/542: babarot
# Fetching repositories for babarot
# Added 308 repositories for babarot
#
# Processing user 113/542: kittinunf
# Fetching repositories for kittinunf
# Added 27 repositories for kittinunf
#
# Processing user 114/542: hewigovens
# Fetching repositories for hewigovens
# Added 216 repositories for hewigovens
#
# Processing user 115/542: tado
# Fetching repositories for tado
# Added 139 repositories for tado
#
# Processing user 116/542: zchee
# Fetching repositories for zchee
# Added 500 repositories for zchee
#
# Processing user 117/542: codeninja819
# Fetching repositories for codeninja819
# Added 50 repositories for codeninja819
#
# Processing user 118/542: sony
# Fetching repositories for sony
# Added 79 repositories for sony
#
# Processing user 119/542: lacolaco
# Fetching repositories for lacolaco
# Added 187 repositories for lacolaco
#
# Processing user 120/542: leemengtw
# Fetching repositories for leemengtw
# Added 157 repositories for leemengtw
#
# Processing user 121/542: zabbix
# Fetching repositories for zabbix
# Added 14 repositories for zabbix
#
# Processing user 122/542: mrkn
# Fetching repositories for mrkn
# Added 311 repositories for mrkn
#
# Processing user 123/542: foostan
# Fetching repositories for foostan
# Added 122 repositories for foostan
#
# Processing user 124/542: houko
# Fetching repositories for houko
# Added 48 repositories for houko
#
# Processing user 125/542: yyuu
# Fetching repositories for yyuu
# Added 147 repositories for yyuu
#
# Processing user 126/542: xerpi
# Fetching repositories for xerpi
# Added 137 repositories for xerpi
#
# Processing user 127/542: yusuke
# Fetching repositories for yusuke
# Added 165 repositories for yusuke
#
# Processing user 128/542: tmk
# Fetching repositories for tmk
# Added 44 repositories for tmk
#
# Processing user 129/542: soda-x
# Fetching repositories for soda-x
# Added 113 repositories for soda-x
#
# Processing user 130/542: 1000ch
# Fetching repositories for 1000ch
# Added 250 repositories for 1000ch
#
# Processing user 131/542: giginet
# Fetching repositories for giginet
# Added 296 repositories for giginet
#
# Processing user 132/542: cj1128
# Fetching repositories for cj1128
# Added 80 repositories for cj1128
#
# Processing user 133/542: fulmicoton
# Fetching repositories for fulmicoton
# Added 126 repositories for fulmicoton
#
# Processing user 134/542: rmackay9
# Fetching repositories for rmackay9
# Added 29 repositories for rmackay9
#
# Processing user 135/542: kitao
# Fetching repositories for kitao
# Added 26 repositories for kitao
#
# Processing user 136/542: huydx
# Fetching repositories for huydx
# Added 127 repositories for huydx
#
# Processing user 137/542: yuiseki
# Fetching repositories for yuiseki
# Added 438 repositories for yuiseki
#
# Processing user 138/542: jfbastien
# Fetching repositories for jfbastien
# Added 69 repositories for jfbastien
#
# Processing user 139/542: daitomanabe
# Fetching repositories for daitomanabe
# Added 217 repositories for daitomanabe
#
# Processing user 140/542: uhyo
# Fetching repositories for uhyo
# Added 197 repositories for uhyo
#
# Processing user 141/542: Songmu
# Fetching repositories for Songmu
# Added 237 repositories for Songmu
#
# Processing user 142/542: wix
# Fetching repositories for wix
# Added 19 repositories for wix
#
# Processing user 143/542: archseer
# Fetching repositories for archseer
# Added 103 repositories for archseer
#
# Processing user 144/542: yosuke-furukawa
# Fetching repositories for yosuke-furukawa
# Added 243 repositories for yosuke-furukawa
#
# Processing user 145/542: kateinoigakukun
# Fetching repositories for kateinoigakukun
# Added 260 repositories for kateinoigakukun
#
# Processing user 146/542: unity3d-jp
# Fetching repositories for unity3d-jp
# Added 68 repositories for unity3d-jp
#
# Processing user 147/542: Jxck
# Fetching repositories for Jxck
# Added 117 repositories for Jxck
#
# Processing user 148/542: konifar
# Fetching repositories for konifar
# Added 148 repositories for konifar
#
# Processing user 149/542: kazu-yamamoto
# Fetching repositories for kazu-yamamoto
# Added 138 repositories for kazu-yamamoto
#
# Processing user 150/542: agibsonccc
# Fetching repositories for agibsonccc
# Added 160 repositories for agibsonccc
#
# Processing user 151/542: mpyw
# Fetching repositories for mpyw
# Added 56 repositories for mpyw
#
# Processing user 152/542: yuki24
# Fetching repositories for yuki24
# Added 61 repositories for yuki24
#
# Processing user 153/542: mayuki
# Fetching repositories for mayuki
# Added 71 repositories for mayuki
#
# Processing user 154/542: shaoanlu
# Fetching repositories for shaoanlu
# Added 42 repositories for shaoanlu
#
# Processing user 155/542: yomotsu
# Fetching repositories for yomotsu
# Added 114 repositories for yomotsu
#
# Processing user 156/542: proppy
# Fetching repositories for proppy
# Added 282 repositories for proppy
#
# Processing user 157/542: cournape
# Fetching repositories for cournape
# Added 148 repositories for cournape
#
# Processing user 158/542: BcRikko
# Fetching repositories for BcRikko
# Added 56 repositories for BcRikko
#
# Processing user 159/542: kou
# Fetching repositories for kou
# Added 324 repositories for kou
#
# Processing user 160/542: h6ah4i
# Fetching repositories for h6ah4i
# Added 142 repositories for h6ah4i
#
# Processing user 161/542: kakutani
# Fetching repositories for kakutani
# Added 57 repositories for kakutani
#
# Processing user 162/542: shuiRong
# Fetching repositories for shuiRong
# Added 47 repositories for shuiRong
#
# Processing user 163/542: Quramy
# Fetching repositories for Quramy
# Added 292 repositories for Quramy
#
# Processing user 164/542: hez2010
# Fetching repositories for hez2010
# Added 108 repositories for hez2010
#
# Processing user 165/542: tigercosmos
# Fetching repositories for tigercosmos
# Added 96 repositories for tigercosmos
#
# Processing user 166/542: ai03-2725
# Fetching repositories for ai03-2725
# Added 49 repositories for ai03-2725
#
# Processing user 167/542: yutkat
# Fetching repositories for yutkat
# Added 107 repositories for yutkat
#
# Processing user 168/542: whitphx
# Fetching repositories for whitphx
# Added 120 repositories for whitphx
#
# Processing user 169/542: tyru
# Fetching repositories for tyru
# Added 222 repositories for tyru
#
# Processing user 170/542: kentaro
# Fetching repositories for kentaro
# Added 376 repositories for kentaro
#
# Processing user 171/542: KotaroNakashima
# Fetching repositories for KotaroNakashima
# Added 5 repositories for KotaroNakashima
#
# Processing user 172/542: remirobert
# Fetching repositories for remirobert
# Added 148 repositories for remirobert
#
# Processing user 173/542: shinh
# Fetching repositories for shinh
# Added 79 repositories for shinh
#
# Processing user 174/542: tanakh
# Fetching repositories for tanakh
# Added 121 repositories for tanakh
#
# Processing user 175/542: 13o-bbr-bbq
# Fetching repositories for 13o-bbr-bbq
# Added 13 repositories for 13o-bbr-bbq
#
# Processing user 176/542: yuin
# Fetching repositories for yuin
# Added 33 repositories for yuin
#
# Processing user 177/542: shirou
# Fetching repositories for shirou
# Added 156 repositories for shirou
#
# Processing user 178/542: sosukesuzuki
# Fetching repositories for sosukesuzuki
# Added 204 repositories for sosukesuzuki
#
# Processing user 179/542: nakabonne
# Fetching repositories for nakabonne
# Added 183 repositories for nakabonne
#
# Processing user 180/542: nobnak
# Fetching repositories for nobnak
# Added 199 repositories for nobnak
#
# Processing user 181/542: penk
# Fetching repositories for penk
# Added 55 repositories for penk
#
# Processing user 182/542: yuroyoro
# Fetching repositories for yuroyoro
# Added 155 repositories for yuroyoro
#
# Processing user 183/542: nuta
# Fetching repositories for nuta
# Added 12 repositories for nuta
#
# Processing user 184/542: KeenS
# Fetching repositories for KeenS
# Added 210 repositories for KeenS
#
# Processing user 185/542: hiroharu-kato
# Fetching repositories for hiroharu-kato
# Added 14 repositories for hiroharu-kato
#
# Processing user 186/542: mehrankmlf
# Fetching repositories for mehrankmlf
# Added 27 repositories for mehrankmlf
#
# Processing user 187/542: tagomoris
# Fetching repositories for tagomoris
# Added 183 repositories for tagomoris
#
# Processing user 188/542: errir503
# Fetching repositories for errir503
# Added 266 repositories for errir503
#
# Processing user 189/542: xeodou
# Fetching repositories for xeodou
# Added 112 repositories for xeodou
#
# Processing user 190/542: knu
# Fetching repositories for knu
# Added 192 repositories for knu
#
# Processing user 191/542: ryota-murakami
# Fetching repositories for ryota-murakami
# Added 158 repositories for ryota-murakami
#
# Processing user 192/542: kyamagu
# Fetching repositories for kyamagu
# Added 28 repositories for kyamagu
#
# Processing user 193/542: sugi-cho
# Fetching repositories for sugi-cho
# Added 101 repositories for sugi-cho
#
# Processing user 194/542: kyubuns
# Fetching repositories for kyubuns
# Added 129 repositories for kyubuns
#
# Processing user 195/542: matthew-andrews
# Fetching repositories for matthew-andrews
# Added 143 repositories for matthew-andrews
#
# Processing user 196/542: sonots
# Fetching repositories for sonots
# Added 332 repositories for sonots
#
# Processing user 197/542: j5ik2o
# Fetching repositories for j5ik2o
# Added 175 repositories for j5ik2o
#
# Processing user 198/542: rakshasa
# Fetching repositories for rakshasa
# Added 35 repositories for rakshasa
#
# Processing user 199/542: heestand-xyz
# Fetching repositories for heestand-xyz
# Added 120 repositories for heestand-xyz
#
# Processing user 200/542: Ohara124c41
# Fetching repositories for Ohara124c41
# Added 142 repositories for Ohara124c41
#
# Processing user 201/542: anshumanv
# Fetching repositories for anshumanv
# Added 72 repositories for anshumanv
#
# Processing user 202/542: higepon
# Fetching repositories for higepon
# Added 67 repositories for higepon
#
# Processing user 203/542: suzana-ilic
# Fetching repositories for suzana-ilic
# Added 33 repositories for suzana-ilic
#
# Processing user 204/542: diwu
# Fetching repositories for diwu
# Added 20 repositories for diwu
#
# Processing user 205/542: naokishibuya
# Fetching repositories for naokishibuya
# Added 9 repositories for naokishibuya
#
# Processing user 206/542: koxudaxi
# Fetching repositories for koxudaxi
# Added 55 repositories for koxudaxi
#
# Processing user 207/542: shyouhei
# Fetching repositories for shyouhei
# Added 64 repositories for shyouhei
#
# Processing user 208/542: Grabacr07
# Fetching repositories for Grabacr07
# Added 14 repositories for Grabacr07
#
# Processing user 209/542: 1024jp
# Fetching repositories for 1024jp
# Added 34 repositories for 1024jp
#
# Processing user 210/542: mitmul
# Fetching repositories for mitmul
# Added 128 repositories for mitmul
#
# Processing user 211/542: mayocream
# Fetching repositories for mayocream
# Added 164 repositories for mayocream
#
# Processing user 212/542: sile
# Fetching repositories for sile
# Added 302 repositories for sile
#
# Processing user 213/542: akueisara
# Fetching repositories for akueisara
# Added 56 repositories for akueisara
#
# Processing user 214/542: hokaccha
# Fetching repositories for hokaccha
# Added 218 repositories for hokaccha
#
# Processing user 215/542: sikachu
# Fetching repositories for sikachu
# Added 166 repositories for sikachu
#
# Processing user 216/542: kazunori279
# Fetching repositories for kazunori279
# Added 29 repositories for kazunori279
#
# Processing user 217/542: siketyan
# Fetching repositories for siketyan
# Added 213 repositories for siketyan
#
# Processing user 218/542: Machine-Learning-Tokyo
# Fetching repositories for Machine-Learning-Tokyo
# Added 46 repositories for Machine-Learning-Tokyo
#
# Processing user 219/542: javascripter
# Fetching repositories for javascripter
# Added 161 repositories for javascripter
#
# Processing user 220/542: suguru
# Fetching repositories for suguru
# Added 48 repositories for suguru
#
# Processing user 221/542: lightsound
# Fetching repositories for lightsound
# Added 70 repositories for lightsound
#
# Processing user 222/542: ryanmcgrath
# Fetching repositories for ryanmcgrath
# Added 58 repositories for ryanmcgrath
#
# Processing user 223/542: ajnart
# Fetching repositories for ajnart
# Added 33 repositories for ajnart
#
# Processing user 224/542: junderw
# Fetching repositories for junderw
# Added 125 repositories for junderw
#
# Processing user 225/542: otiai10
# Fetching repositories for otiai10
# Added 338 repositories for otiai10
#
# Processing user 226/542: aocattleya
# Fetching repositories for aocattleya
# Added 56 repositories for aocattleya
#
# Processing user 227/542: hashrock
# Fetching repositories for hashrock
# Added 212 repositories for hashrock
#
# Processing user 228/542: wynand1004
# Fetching repositories for wynand1004
# Added 13 repositories for wynand1004
#
# Processing user 229/542: piroor
# Fetching repositories for piroor
# Added 171 repositories for piroor
#
# Processing user 230/542: AAkira
# Fetching repositories for AAkira
# Added 51 repositories for AAkira
#
# Processing user 231/542: zlq4863947
# Fetching repositories for zlq4863947
# Added 54 repositories for zlq4863947
#
# Processing user 232/542: ianlewis
# Fetching repositories for ianlewis
# Added 168 repositories for ianlewis
#
# Processing user 233/542: Lewuathe
# Fetching repositories for Lewuathe
# Added 118 repositories for Lewuathe
#
# Processing user 234/542: syumai
# Fetching repositories for syumai
# Added 175 repositories for syumai
#
# Processing user 235/542: iwiwi
# Fetching repositories for iwiwi
# Added 51 repositories for iwiwi
#
# Processing user 236/542: koic
# Fetching repositories for koic
# Added 278 repositories for koic
#
# Processing user 237/542: taku910
# Fetching repositories for taku910
# Added 22 repositories for taku910
#
# Processing user 238/542: blivesta
# Fetching repositories for blivesta
# Added 28 repositories for blivesta
#
# Processing user 239/542: Ryo-N7
# Fetching repositories for Ryo-N7
# Added 63 repositories for Ryo-N7
#
# Processing user 240/542: hannoeru
# Fetching repositories for hannoeru
# Added 124 repositories for hannoeru
#
# Processing user 241/542: shirakaba
# Fetching repositories for shirakaba
# Added 168 repositories for shirakaba
#
# Processing user 242/542: E869120
# Fetching repositories for E869120
# Added 13 repositories for E869120
#
# Processing user 243/542: idiotWu
# Fetching repositories for idiotWu
# Added 39 repositories for idiotWu
#
# Processing user 244/542: davetang
# Fetching repositories for davetang
# Added 86 repositories for davetang
#
# Processing user 245/542: pine
# Fetching repositories for pine
# Added 271 repositories for pine
#
# Processing user 246/542: minaminao
# Fetching repositories for minaminao
# Added 143 repositories for minaminao
#
# Processing user 247/542: ynagatomo
# Fetching repositories for ynagatomo
# Added 37 repositories for ynagatomo
#
# Processing user 248/542: Haruma-K
# Fetching repositories for Haruma-K
# Added 19 repositories for Haruma-K
#
# Processing user 249/542: wadackel
# Fetching repositories for wadackel
# Added 127 repositories for wadackel
#
# Processing user 250/542: zonuexe
# Fetching repositories for zonuexe
# Added 354 repositories for zonuexe
#
# Processing user 251/542: kitasuke
# Fetching repositories for kitasuke
# Added 48 repositories for kitasuke
#
# Processing user 252/542: katchion13
# Fetching repositories for katchion13
# Added 20 repositories for katchion13
#
# Processing user 253/542: t32k
# Fetching repositories for t32k
# Added 92 repositories for t32k
#
# Processing user 254/542: ymotongpoo
# Fetching repositories for ymotongpoo
# Added 203 repositories for ymotongpoo
#
# Processing user 255/542: komagata
# Fetching repositories for komagata
# Added 188 repositories for komagata
#
# Processing user 256/542: Tedko
# Fetching repositories for Tedko
# Added 56 repositories for Tedko
#
# Processing user 257/542: takuoka
# Fetching repositories for takuoka
# Added 67 repositories for takuoka
#
# Processing user 258/542: masuhara
# Fetching repositories for masuhara
# Added 113 repositories for masuhara
#
# Processing user 259/542: axzxs2001
# Fetching repositories for axzxs2001
# Added 63 repositories for axzxs2001
#
# Processing user 260/542: chengstone
# Fetching repositories for chengstone
# Added 126 repositories for chengstone
#
# Processing user 261/542: lin-toto
# Fetching repositories for lin-toto
# Added 26 repositories for lin-toto
#
# Processing user 262/542: hayatoito
# Fetching repositories for hayatoito
# Added 64 repositories for hayatoito
#
# Processing user 263/542: ChunML
# Fetching repositories for ChunML
# Added 36 repositories for ChunML
#
# Processing user 264/542: yuki-koyama
# Fetching repositories for yuki-koyama
# Added 59 repositories for yuki-koyama
#
# Processing user 265/542: uwi
# Fetching repositories for uwi
# Added 9 repositories for uwi
#
# Processing user 266/542: JDDKCN
# Fetching repositories for JDDKCN
# Added 24 repositories for JDDKCN
#
# Processing user 267/542: cognitom
# Fetching repositories for cognitom
# Added 145 repositories for cognitom
#
# Processing user 268/542: yuk1ty
# Fetching repositories for yuk1ty
# Added 130 repositories for yuk1ty
#
# Processing user 269/542: nineties
# Fetching repositories for nineties
# Added 36 repositories for nineties
#
# Processing user 270/542: koron
# Fetching repositories for koron
# Added 357 repositories for koron
#
# Processing user 271/542: ninjinkun
# Fetching repositories for ninjinkun
# Added 36 repositories for ninjinkun
#
# Processing user 272/542: ikegami-yukino
# Fetching repositories for ikegami-yukino
# Added 42 repositories for ikegami-yukino
#
# Processing user 273/542: MasayukiSuda
# Fetching repositories for MasayukiSuda
# Added 23 repositories for MasayukiSuda
#
# Processing user 274/542: joker1007
# Fetching repositories for joker1007
# Added 196 repositories for joker1007
#
# Processing user 275/542: nov
# Fetching repositories for nov
# Added 165 repositories for nov
#
# Processing user 276/542: suzuki-shunsuke
# Fetching repositories for suzuki-shunsuke
# Added 500 repositories for suzuki-shunsuke
#
# Processing user 277/542: ntddk
# Fetching repositories for ntddk
# Added 50 repositories for ntddk
#
# Processing user 278/542: ibuninngu
# Fetching repositories for ibuninngu
# Added 0 repositories for ibuninngu
#
# Processing user 279/542: EsProgram
# Fetching repositories for EsProgram
# Added 41 repositories for EsProgram
#
# Processing user 280/542: naotokui
# Fetching repositories for naotokui
# Added 95 repositories for naotokui
#
# Processing user 281/542: soutaro
# Fetching repositories for soutaro
# Added 184 repositories for soutaro
#
# Processing user 282/542: sgr-ksmt
# Fetching repositories for sgr-ksmt
# Added 131 repositories for sgr-ksmt
#
# Processing user 283/542: shuhei
# Fetching repositories for shuhei
# Added 186 repositories for shuhei
#
# Processing user 284/542: yanex
# Fetching repositories for yanex
# Added 21 repositories for yanex
#
# Processing user 285/542: odashi
# Fetching repositories for odashi
# Added 65 repositories for odashi
#
# Processing user 286/542: kitasenjudesign
# Fetching repositories for kitasenjudesign
# Added 41 repositories for kitasenjudesign
#
# Processing user 287/542: wheatup
# Fetching repositories for wheatup
# Added 61 repositories for wheatup
#
# Processing user 288/542: Rokt33r
# Fetching repositories for Rokt33r
# Added 106 repositories for Rokt33r
#
# Processing user 289/542: rakina
# Fetching repositories for rakina
# Added 22 repositories for rakina
#
# Processing user 290/542: polm
# Fetching repositories for polm
# Added 136 repositories for polm
#
# Processing user 291/542: hideakitai
# Fetching repositories for hideakitai
# Added 106 repositories for hideakitai
#
# Processing user 292/542: SystemErrorWang
# Fetching repositories for SystemErrorWang
# Added 24 repositories for SystemErrorWang
#
# Processing user 293/542: satoshi0212
# Fetching repositories for satoshi0212
# Added 29 repositories for satoshi0212
#
# Processing user 294/542: marioyc
# Fetching repositories for marioyc
# Added 53 repositories for marioyc
#
# Processing user 295/542: takayama-lily
# Fetching repositories for takayama-lily
# Added 34 repositories for takayama-lily
#
# Processing user 296/542: yasulab
# Fetching repositories for yasulab
# Added 67 repositories for yasulab
#
# Processing user 297/542: frandiox
# Fetching repositories for frandiox
# Added 128 repositories for frandiox
#
# Processing user 298/542: egisatoshi
# Fetching repositories for egisatoshi
# Added 77 repositories for egisatoshi
#
# Processing user 299/542: moskomule
# Fetching repositories for moskomule
# Added 76 repositories for moskomule
#
# Processing user 300/542: neet
# Fetching repositories for neet
# Added 83 repositories for neet
#
# Processing user 301/542: JasonkayZK
# Fetching repositories for JasonkayZK
# Added 96 repositories for JasonkayZK
#
# Processing user 302/542: atsushieno
# Fetching repositories for atsushieno
# Added 263 repositories for atsushieno
#
# Processing user 303/542: KyoheiG3
# Fetching repositories for KyoheiG3
# Added 48 repositories for KyoheiG3
#
# Processing user 304/542: upura
# Fetching repositories for upura
# Added 83 repositories for upura
#
# Processing user 305/542: shibayan
# Fetching repositories for shibayan
# Added 115 repositories for shibayan
#
# Processing user 306/542: Cloudef
# Fetching repositories for Cloudef
# Added 129 repositories for Cloudef
#
# Processing user 307/542: pasta-auto
# Fetching repositories for pasta-auto
# Added 2 repositories for pasta-auto
#
# Processing user 308/542: Saqoosha
# Fetching repositories for Saqoosha
# Added 53 repositories for Saqoosha
#
# Processing user 309/542: amachang
# Fetching repositories for amachang
# Added 58 repositories for amachang
#
# Processing user 310/542: ojii
# Fetching repositories for ojii
# Added 207 repositories for ojii
#
# Processing user 311/542: kodai100
# Fetching repositories for kodai100
# Added 118 repositories for kodai100
#
# Processing user 312/542: Aixile
# Fetching repositories for Aixile
# Added 28 repositories for Aixile
#
# Processing user 313/542: kaustubhhiware
# Fetching repositories for kaustubhhiware
# Added 121 repositories for kaustubhhiware
#
# Processing user 314/542: hak
# Fetching repositories for hak
# Added 23 repositories for hak
#
# Processing user 315/542: everpeace
# Fetching repositories for everpeace
# Added 251 repositories for everpeace
#
# Processing user 316/542: k-takata
# Fetching repositories for k-takata
# Added 82 repositories for k-takata
#
# Processing user 317/542: kazuki43zoo
# Fetching repositories for kazuki43zoo
# Added 204 repositories for kazuki43zoo
#
# Processing user 318/542: yuna0x0
# Fetching repositories for yuna0x0
# Added 300 repositories for yuna0x0
#
# Processing user 319/542: aviatesk
# Fetching repositories for aviatesk
# Added 120 repositories for aviatesk
#
# Processing user 320/542: jay-kumogata
# Fetching repositories for jay-kumogata
# Added 15 repositories for jay-kumogata
#
# Processing user 321/542: lloydmeta
# Fetching repositories for lloydmeta
# Added 256 repositories for lloydmeta
#
# Processing user 322/542: lukas-reineke
# Fetching repositories for lukas-reineke
# Added 77 repositories for lukas-reineke
#
# Processing user 323/542: qnighy
# Fetching repositories for qnighy
# Added 222 repositories for qnighy
#
# Processing user 324/542: hirocaster
# Fetching repositories for hirocaster
# Added 253 repositories for hirocaster
#
# Processing user 325/542: YuriSizuku
# Fetching repositories for YuriSizuku
# Added 34 repositories for YuriSizuku
#
# Processing user 326/542: Chakazul
# Fetching repositories for Chakazul
# Added 9 repositories for Chakazul
#
# Processing user 327/542: Live2D
# Fetching repositories for Live2D
# Added 18 repositories for Live2D
#
# Processing user 328/542: pwim
# Fetching repositories for pwim
# Added 113 repositories for pwim
#
# Processing user 329/542: ngs
# Fetching repositories for ngs
# Added 99 repositories for ngs
#
# Processing user 330/542: predominant
# Fetching repositories for predominant
# Added 205 repositories for predominant
#
# Processing user 331/542: sachaos
# Fetching repositories for sachaos
# Added 133 repositories for sachaos
#
# Processing user 332/542: sonsongithub
# Fetching repositories for sonsongithub
# Added 163 repositories for sonsongithub
#
# Processing user 333/542: kawasima
# Fetching repositories for kawasima
# Added 266 repositories for kawasima
#
# Processing user 334/542: yukinaga
# Fetching repositories for yukinaga
# Added 62 repositories for yukinaga
#
# Processing user 335/542: eagletmt
# Fetching repositories for eagletmt
# Added 261 repositories for eagletmt
#
# Processing user 336/542: koki0702
# Fetching repositories for koki0702
# Added 22 repositories for koki0702
#
# Processing user 337/542: JPCERTCC
# Fetching repositories for JPCERTCC
# Added 36 repositories for JPCERTCC
#
# Processing user 338/542: ahomu
# Fetching repositories for ahomu
# Added 61 repositories for ahomu
#
# Processing user 339/542: yoshiko-pg
# Fetching repositories for yoshiko-pg
# Added 28 repositories for yoshiko-pg
#
# Processing user 340/542: moznion
# Fetching repositories for moznion
# Added 449 repositories for moznion
#
# Processing user 341/542: akameco
# Fetching repositories for akameco
# Added 237 repositories for akameco
#
# Processing user 342/542: chokkan
# Fetching repositories for chokkan
# Added 18 repositories for chokkan
#
# Processing user 343/542: mactkg
# Fetching repositories for mactkg
# Added 271 repositories for mactkg
#
# Processing user 344/542: yorkxin
# Fetching repositories for yorkxin
# Added 33 repositories for yorkxin
#
# Processing user 345/542: summerwind
# Fetching repositories for summerwind
# Added 49 repositories for summerwind
#
# Processing user 346/542: YutaroOgawa
# Fetching repositories for YutaroOgawa
# Added 18 repositories for YutaroOgawa
#
# Processing user 347/542: mopemope
# Fetching repositories for mopemope
# Added 123 repositories for mopemope
#
# Processing user 348/542: takefumi-yoshii
# Fetching repositories for takefumi-yoshii
# Added 102 repositories for takefumi-yoshii
#
# Processing user 349/542: natronics
# Fetching repositories for natronics
# Added 66 repositories for natronics
#
# Processing user 350/542: lotz84
# Fetching repositories for lotz84
# Added 85 repositories for lotz84
#
# Processing user 351/542: marocchino
# Fetching repositories for marocchino
# Added 231 repositories for marocchino
#
# Processing user 352/542: guitarrapc
# Fetching repositories for guitarrapc
# Added 166 repositories for guitarrapc
#
# Processing user 353/542: moneyforward
# Fetching repositories for moneyforward
# Added 93 repositories for moneyforward
#
# Processing user 354/542: famasoon
# Fetching repositories for famasoon
# Added 186 repositories for famasoon
#
# Processing user 355/542: tatsuyah
# Fetching repositories for tatsuyah
# Added 35 repositories for tatsuyah
#
# Processing user 356/542: bannzai
# Fetching repositories for bannzai
# Added 223 repositories for bannzai
#
# Processing user 357/542: uchan-nos
# Fetching repositories for uchan-nos
# Added 51 repositories for uchan-nos
#
# Processing user 358/542: rdiankov
# Fetching repositories for rdiankov
# Added 12 repositories for rdiankov
#
# Processing user 359/542: 1amageek
# Fetching repositories for 1amageek
# Added 188 repositories for 1amageek
#
# Processing user 360/542: hiloki
# Fetching repositories for hiloki
# Added 119 repositories for hiloki
#
# Processing user 361/542: fumieval
# Fetching repositories for fumieval
# Added 207 repositories for fumieval
#
# Processing user 362/542: magurotuna
# Fetching repositories for magurotuna
# Added 159 repositories for magurotuna
#
# Processing user 363/542: sotarok
# Fetching repositories for sotarok
# Added 26 repositories for sotarok
#
# Processing user 364/542: aliceinwire
# Fetching repositories for aliceinwire
# Added 183 repositories for aliceinwire
#
# Processing user 365/542: masarakki
# Fetching repositories for masarakki
# Added 81 repositories for masarakki
#
# Processing user 366/542: hiroyuki-kasai
# Fetching repositories for hiroyuki-kasai
# Added 17 repositories for hiroyuki-kasai
#
# Processing user 367/542: Layzie
# Fetching repositories for Layzie
# Added 66 repositories for Layzie
#
# Processing user 368/542: atyenoria
# Fetching repositories for atyenoria
# Added 220 repositories for atyenoria
#
# Processing user 369/542: conao3
# Fetching repositories for conao3
# Added 462 repositories for conao3
#
# Processing user 370/542: kboy-silvergym
# Fetching repositories for kboy-silvergym
# Added 55 repositories for kboy-silvergym
#
# Processing user 371/542: stomita
# Fetching repositories for stomita
# Added 79 repositories for stomita
#
# Processing user 372/542: sureshmurali
# Fetching repositories for sureshmurali
# Added 14 repositories for sureshmurali
#
# Processing user 373/542: naruhitotakei
# Fetching repositories for naruhitotakei
# Added 23 repositories for naruhitotakei
#
# Processing user 374/542: miyabi
# Fetching repositories for miyabi
# Added 65 repositories for miyabi
#
# Processing user 375/542: k-okada
# Fetching repositories for k-okada
# Added 316 repositories for k-okada
#
# Processing user 376/542: moriyoshi
# Fetching repositories for moriyoshi
# Added 201 repositories for moriyoshi
#
# Processing user 377/542: fontworks-fonts
# Fetching repositories for fontworks-fonts
# Added 7 repositories for fontworks-fonts
#
# Processing user 378/542: sobri909
# Fetching repositories for sobri909
# Added 20 repositories for sobri909
#
# Processing user 379/542: matsui528
# Fetching repositories for matsui528
# Added 39 repositories for matsui528
#
# Processing user 380/542: asukaminato0721
# Fetching repositories for asukaminato0721
# Added 147 repositories for asukaminato0721
#
# Processing user 381/542: dshukertjr
# Fetching repositories for dshukertjr
# Added 148 repositories for dshukertjr
#
# Processing user 382/542: shiraji
# Fetching repositories for shiraji
# Added 137 repositories for shiraji
#
# Processing user 383/542: mitchan0321
# Fetching repositories for mitchan0321
# Added 5 repositories for mitchan0321
#
# Processing user 384/542: karupanerura
# Fetching repositories for karupanerura
# Added 308 repositories for karupanerura
#
# Processing user 385/542: yuichiroharai
# Fetching repositories for yuichiroharai
# Added 21 repositories for yuichiroharai
#
# Processing user 386/542: aitikgupta
# Fetching repositories for aitikgupta
# Added 60 repositories for aitikgupta
#
# Processing user 387/542: shigeki
# Fetching repositories for shigeki
# Added 52 repositories for shigeki
#
# Processing user 388/542: orisano
# Fetching repositories for orisano
# Added 255 repositories for orisano
#
# Processing user 389/542: Pitu
# Fetching repositories for Pitu
# Added 20 repositories for Pitu
#
# Processing user 390/542: maropu
# Fetching repositories for maropu
# Added 63 repositories for maropu
#
# Processing user 391/542: karlcow
# Fetching repositories for karlcow
# Added 97 repositories for karlcow
#
# Processing user 392/542: kjur
# Fetching repositories for kjur
# Added 43 repositories for kjur
#
# Processing user 393/542: inket
# Fetching repositories for inket
# Added 72 repositories for inket
#
# Processing user 394/542: andriiginting
# Fetching repositories for andriiginting
# Added 88 repositories for andriiginting
#
# Processing user 395/542: takuma104
# Fetching repositories for takuma104
# Added 20 repositories for takuma104
#
# Processing user 396/542: ktr0731
# Fetching repositories for ktr0731
# Added 136 repositories for ktr0731
#
# Processing user 397/542: securas
# Fetching repositories for securas
# Added 22 repositories for securas
#
# Processing user 398/542: rejasupotaro
# Fetching repositories for rejasupotaro
# Added 88 repositories for rejasupotaro
#
# Processing user 399/542: melpon
# Fetching repositories for melpon
# Added 59 repositories for melpon
#
# Processing user 400/542: willnet
# Fetching repositories for willnet
# Added 264 repositories for willnet
#
# Processing user 401/542: bcgameProject
# Fetching repositories for bcgameProject
# Added 1 repositories for bcgameProject
#
# Processing user 402/542: kozo2
# Fetching repositories for kozo2
# Added 388 repositories for kozo2
#
# Processing user 403/542: nyoki-mtl
# Fetching repositories for nyoki-mtl
# Added 10 repositories for nyoki-mtl
#
# Processing user 404/542: aajisaka
# Fetching repositories for aajisaka
# Added 35 repositories for aajisaka
#
# Processing user 405/542: abeake
# Fetching repositories for abeake
# Added 8 repositories for abeake
#
# Processing user 406/542: studiomohawk
# Fetching repositories for studiomohawk
# Added 67 repositories for studiomohawk
#
# Processing user 407/542: tuian
# Fetching repositories for tuian
# Added 500 repositories for tuian
#
# Processing user 408/542: suin
# Fetching repositories for suin
# Added 190 repositories for suin
#
# Processing user 409/542: yamahigashi
# Fetching repositories for yamahigashi
# Added 62 repositories for yamahigashi
#
# Processing user 410/542: fukayatsu
# Fetching repositories for fukayatsu
# Added 265 repositories for fukayatsu
#
# Processing user 411/542: rayston92
# Fetching repositories for rayston92
# Added 38 repositories for rayston92
#
# Processing user 412/542: shspage
# Fetching repositories for shspage
# Added 13 repositories for shspage
#
# Processing user 413/542: shogo4405
# Fetching repositories for shogo4405
# Added 19 repositories for shogo4405
#
# Processing user 414/542: ariaghora
# Fetching repositories for ariaghora
# Added 66 repositories for ariaghora
#
# Processing user 415/542: dtan4
# Fetching repositories for dtan4
# Added 259 repositories for dtan4
#
# Processing user 416/542: komietty
# Fetching repositories for komietty
# Added 22 repositories for komietty
#
# Processing user 417/542: larryshamalama
# Fetching repositories for larryshamalama
# Added 74 repositories for larryshamalama
#
# Processing user 418/542: fqj1994
# Fetching repositories for fqj1994
# Added 29 repositories for fqj1994
#
# Processing user 419/542: teppeis
# Fetching repositories for teppeis
# Added 182 repositories for teppeis
#
# Processing user 420/542: MagicalTux
# Fetching repositories for MagicalTux
# Added 96 repositories for MagicalTux
#
# Processing user 421/542: guregu
# Fetching repositories for guregu
# Added 86 repositories for guregu
#
# Processing user 422/542: int128
# Fetching repositories for int128
# Added 281 repositories for int128
#
# Processing user 423/542: BBleae
# Fetching repositories for BBleae
# Added 57 repositories for BBleae
#
# Processing user 424/542: fumiyasac
# Fetching repositories for fumiyasac
# Added 185 repositories for fumiyasac
#
# Processing user 425/542: r-plus
# Fetching repositories for r-plus
# Added 164 repositories for r-plus
#
# Processing user 426/542: sinhrks
# Fetching repositories for sinhrks
# Added 50 repositories for sinhrks
#
# Processing user 427/542: miyako
# Fetching repositories for miyako
# Added 500 repositories for miyako
#
# Processing user 428/542: arubdesu
# Fetching repositories for arubdesu
# Added 79 repositories for arubdesu
#
# Processing user 429/542: chibash
# Fetching repositories for chibash
# Added 4 repositories for chibash
#
# Processing user 430/542: yoshiori
# Fetching repositories for yoshiori
# Added 121 repositories for yoshiori
#
# Processing user 431/542: swdyh
# Fetching repositories for swdyh
# Added 35 repositories for swdyh
#
# Processing user 432/542: micnncim
# Fetching repositories for micnncim
# Added 198 repositories for micnncim
#
# Processing user 433/542: nicolas-raoul
# Fetching repositories for nicolas-raoul
# Added 211 repositories for nicolas-raoul
#
# Processing user 434/542: uiryuu
# Fetching repositories for uiryuu
# Added 16 repositories for uiryuu
#
# Processing user 435/542: ionicc
# Fetching repositories for ionicc
# Added 58 repositories for ionicc
#
# Processing user 436/542: saitoha
# Fetching repositories for saitoha
# Added 80 repositories for saitoha
#
# Processing user 437/542: alphaKAI
# Fetching repositories for alphaKAI
# Added 150 repositories for alphaKAI
#
# Processing user 438/542: halogenandtoast
# Fetching repositories for halogenandtoast
# Added 121 repositories for halogenandtoast
#
# Processing user 439/542: kuy
# Fetching repositories for kuy
# Added 183 repositories for kuy
#
# Processing user 440/542: hamukazu
# Fetching repositories for hamukazu
# Added 70 repositories for hamukazu
#
# Processing user 441/542: nullpo-head
# Fetching repositories for nullpo-head
# Added 56 repositories for nullpo-head
#
# Processing user 442/542: linxGnu
# Fetching repositories for linxGnu
# Added 38 repositories for linxGnu
#
# Processing user 443/542: hibariya
# Fetching repositories for hibariya
# Added 113 repositories for hibariya
#
# Processing user 444/542: norotime
# Fetching repositories for norotime
# Added 2 repositories for norotime
#
# Processing user 445/542: masayuki0812
# Fetching repositories for masayuki0812
# Added 4 repositories for masayuki0812
#
# Processing user 446/542: LanceMoe
# Fetching repositories for LanceMoe
# Added 53 repositories for LanceMoe
#
# Processing user 447/542: patio11
# Fetching repositories for patio11
# Added 25 repositories for patio11
#
# Processing user 448/542: kananinirav
# Fetching repositories for kananinirav
# Added 51 repositories for kananinirav
#
# Processing user 449/542: seanchas116
# Fetching repositories for seanchas116
# Added 188 repositories for seanchas116
#
# Processing user 450/542: mirakui
# Fetching repositories for mirakui
# Added 112 repositories for mirakui
#
# Processing user 451/542: taichi
# Fetching repositories for taichi
# Added 128 repositories for taichi
#
# Processing user 452/542: coord-e
# Fetching repositories for coord-e
# Added 116 repositories for coord-e
#
# Processing user 453/542: uzulla
# Fetching repositories for uzulla
# Added 148 repositories for uzulla
#
# Processing user 454/542: LaoshuBaby
# Fetching repositories for LaoshuBaby
# Added 134 repositories for LaoshuBaby
#
# Processing user 455/542: nnn1590
# Fetching repositories for nnn1590
# Added 217 repositories for nnn1590
#
# Processing user 456/542: supermomonga
# Fetching repositories for supermomonga
# Added 247 repositories for supermomonga
#
# Processing user 457/542: mitsuruog
# Fetching repositories for mitsuruog
# Added 184 repositories for mitsuruog
#
# Processing user 458/542: yoichiro
# Fetching repositories for yoichiro
# Added 125 repositories for yoichiro
#
# Processing user 459/542: nobuyuki83
# Fetching repositories for nobuyuki83
# Added 48 repositories for nobuyuki83
#
# Processing user 460/542: vaaaaanquish
# Fetching repositories for vaaaaanquish
# Added 66 repositories for vaaaaanquish
#
# Processing user 461/542: mapconcierge
# Fetching repositories for mapconcierge
# Added 281 repositories for mapconcierge
#
# Processing user 462/542: kurone-kito
# Fetching repositories for kurone-kito
# Added 53 repositories for kurone-kito
#
# Processing user 463/542: lyokato
# Fetching repositories for lyokato
# Added 104 repositories for lyokato
#
# Processing user 464/542: walf443
# Fetching repositories for walf443
# Added 168 repositories for walf443
#
# Processing user 465/542: yuki-kimoto
# Fetching repositories for yuki-kimoto
# Added 248 repositories for yuki-kimoto
#
# Processing user 466/542: koriym
# Fetching repositories for koriym
# Added 208 repositories for koriym
#
# Processing user 467/542: takahashim
# Fetching repositories for takahashim
# Added 333 repositories for takahashim
#
# Processing user 468/542: shibukawa
# Fetching repositories for shibukawa
# Added 271 repositories for shibukawa
#
# Processing user 469/542: hirose31
# Fetching repositories for hirose31
# Added 174 repositories for hirose31
#
# Processing user 470/542: Richard-Burns
# Fetching repositories for Richard-Burns
# Added 29 repositories for Richard-Burns
#
# Processing user 471/542: edom18
# Fetching repositories for edom18
# Added 178 repositories for edom18
#
# Processing user 472/542: youtalk
# Fetching repositories for youtalk
# Added 92 repositories for youtalk
#
# Processing user 473/542: slankdev
# Fetching repositories for slankdev
# Added 81 repositories for slankdev
#
# Processing user 474/542: NalaGinrut
# Fetching repositories for NalaGinrut
# Added 67 repositories for NalaGinrut
#
# Processing user 475/542: d-date
# Fetching repositories for d-date
# Added 107 repositories for d-date
#
# Processing user 476/542: nekokak
# Fetching repositories for nekokak
# Added 65 repositories for nekokak
#
# Processing user 477/542: kevincobain2000
# Fetching repositories for kevincobain2000
# Added 147 repositories for kevincobain2000
#
# Processing user 478/542: bluele
# Fetching repositories for bluele
# Added 125 repositories for bluele
#
# Processing user 479/542: syoichi
# Fetching repositories for syoichi
# Added 36 repositories for syoichi
#
# Processing user 480/542: megabitsenmzq
# Fetching repositories for megabitsenmzq
# Added 37 repositories for megabitsenmzq
#
# Processing user 481/542: dvcrn
# Fetching repositories for dvcrn
# Added 140 repositories for dvcrn
#
# Processing user 482/542: pixiv
# Fetching repositories for pixiv
# Added 55 repositories for pixiv
#
# Processing user 483/542: k0i
# Fetching repositories for k0i
# Added 18 repositories for k0i
#
# Processing user 484/542: GomaGoma676
# Fetching repositories for GomaGoma676
# Added 67 repositories for GomaGoma676
#
# Processing user 485/542: kitak
# Fetching repositories for kitak
# Added 165 repositories for kitak
#
# Processing user 486/542: alantian
# Fetching repositories for alantian
# Added 14 repositories for alantian
#
# Processing user 487/542: okuryu
# Fetching repositories for okuryu
# Added 132 repositories for okuryu
#
# Processing user 488/542: anharu2394
# Fetching repositories for anharu2394
# Added 57 repositories for anharu2394
#
# Processing user 489/542: egoist-sx
# Fetching repositories for egoist-sx
# Added 30 repositories for egoist-sx
#
# Processing user 490/542: mootoh
# Fetching repositories for mootoh
# Added 70 repositories for mootoh
#
# Processing user 491/542: thorikawa
# Fetching repositories for thorikawa
# Added 211 repositories for thorikawa
#
# Processing user 492/542: otsune
# Fetching repositories for otsune
# Added 9 repositories for otsune
#
# Processing user 493/542: 256-daisuki
# Fetching repositories for 256-daisuki
# Added 10 repositories for 256-daisuki
#
# Processing user 494/542: kumagi
# Fetching repositories for kumagi
# Added 122 repositories for kumagi
#
# Processing user 495/542: tokorom
# Fetching repositories for tokorom
# Added 204 repositories for tokorom
#
# Processing user 496/542: tyoshikawa1106
# Fetching repositories for tyoshikawa1106
# Added 226 repositories for tyoshikawa1106
#
# Processing user 497/542: samundrak
# Fetching repositories for samundrak
# Added 169 repositories for samundrak
#
# Processing user 498/542: m3m0r7
# Fetching repositories for m3m0r7
# Added 24 repositories for m3m0r7
#
# Processing user 499/542: lhl
# Fetching repositories for lhl
# Added 99 repositories for lhl
#
# Processing user 500/542: fenomas
# Fetching repositories for fenomas
# Added 74 repositories for fenomas
#
# Processing user 501/542: vanhuyz
# Fetching repositories for vanhuyz
# Added 29 repositories for vanhuyz
#
# Processing user 502/542: yshrsmz
# Fetching repositories for yshrsmz
# Added 155 repositories for yshrsmz
#
# Processing user 503/542: Kimtaro
# Fetching repositories for Kimtaro
# Added 43 repositories for Kimtaro
#
# Processing user 504/542: davidnguyen11
# Fetching repositories for davidnguyen11
# Added 135 repositories for davidnguyen11
#
# Processing user 505/542: ryo24
# Fetching repositories for ryo24
# Added 38 repositories for ryo24
#
# Processing user 506/542: woodrush
# Fetching repositories for woodrush
# Added 43 repositories for woodrush
#
# Processing user 507/542: Dosugamea
# Fetching repositories for Dosugamea
# Added 92 repositories for Dosugamea
#
# Processing user 508/542: gimite
# Fetching repositories for gimite
# Added 35 repositories for gimite
#
# Processing user 509/542: himkt
# Fetching repositories for himkt
# Added 174 repositories for himkt
#
# Processing user 510/542: sienori
# Fetching repositories for sienori
# Added 20 repositories for sienori
#
# Processing user 511/542: ucan-lab
# Fetching repositories for ucan-lab
# Added 125 repositories for ucan-lab
#
# Processing user 512/542: 2bbb
# Fetching repositories for 2bbb
# Added 277 repositories for 2bbb
#
# Processing user 513/542: miquelcampos
# Fetching repositories for miquelcampos
# Added 36 repositories for miquelcampos
#
# Processing user 514/542: kissy24
# Fetching repositories for kissy24
# Added 30 repositories for kissy24
#
# Processing user 515/542: yoichitgy
# Fetching repositories for yoichitgy
# Added 38 repositories for yoichitgy
#
# Processing user 516/542: kotakanbe
# Fetching repositories for kotakanbe
# Added 30 repositories for kotakanbe
#
# Processing user 517/542: xfoxfu
# Fetching repositories for xfoxfu
# Added 64 repositories for xfoxfu
#
# Processing user 518/542: jojonki
# Fetching repositories for jojonki
# Added 131 repositories for jojonki
#
# Processing user 519/542: aamine
# Fetching repositories for aamine
# Added 22 repositories for aamine
#
# Processing user 520/542: deatiger
# Fetching repositories for deatiger
# Added 30 repositories for deatiger
#
# Processing user 521/542: soskek
# Fetching repositories for soskek
# Added 79 repositories for soskek
#
# Processing user 522/542: SoraSuegami
# Fetching repositories for SoraSuegami
# Added 57 repositories for SoraSuegami
#
# Processing user 523/542: MaxMEllon
# Fetching repositories for MaxMEllon
# Added 246 repositories for MaxMEllon
#
# Processing user 524/542: taiki45
# Fetching repositories for taiki45
# Added 136 repositories for taiki45
#
# Processing user 525/542: ericnakagawa
# Fetching repositories for ericnakagawa
# Added 37 repositories for ericnakagawa
#
# Processing user 526/542: creasty
# Fetching repositories for creasty
# Added 79 repositories for creasty
#
# Processing user 527/542: KeithYokoma
# Fetching repositories for KeithYokoma
# Added 109 repositories for KeithYokoma
#
# Processing user 528/542: ubugeeei
# Fetching repositories for ubugeeei
# Added 107 repositories for ubugeeei
#
# Processing user 529/542: yanarchy
# Fetching repositories for yanarchy
# Added 82 repositories for yanarchy
#
# Processing user 530/542: yandod
# Fetching repositories for yandod
# Added 147 repositories for yandod
#
# Processing user 531/542: konn
# Fetching repositories for konn
# Added 250 repositories for konn
#
# Processing user 532/542: moro
# Fetching repositories for moro
# Added 79 repositories for moro
#
# Processing user 533/542: icyflame
# Fetching repositories for icyflame
# Added 305 repositories for icyflame
#
# Processing user 534/542: kazuhikoarase
# Fetching repositories for kazuhikoarase
# Added 48 repositories for kazuhikoarase
#
# Processing user 535/542: ArvinH
# Fetching repositories for ArvinH
# Added 77 repositories for ArvinH
#
# Processing user 536/542: hiroakioishi
# Fetching repositories for hiroakioishi
# Added 36 repositories for hiroakioishi
#
# Processing user 537/542: morizotter
# Fetching repositories for morizotter
# Added 101 repositories for morizotter
#
# Processing user 538/542: miyaichi
# Fetching repositories for miyaichi
# Added 67 repositories for miyaichi
#
# Processing user 539/542: OTL
# Fetching repositories for OTL
# Added 94 repositories for OTL
#
# Processing user 540/542: naoto0804
# Fetching repositories for naoto0804
# Added 19 repositories for naoto0804
#
# Processing user 541/542: yaotti
# Fetching repositories for yaotti
# Added 44 repositories for yaotti
#
# Processing user 542/542: JohnEstropia
# Fetching repositories for JohnEstropia
# Added 59 repositories for JohnEstropia
#
# Data saved to tokyo_users_20241031_004140.csv and tokyo_repos_20241031_004140.csv
# Total users processed: 542
# Total repositories processed: 67076

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import re

def load_data(users_file, repos_file):
    users_df = pd.read_csv(users_file)
    repos_df = pd.read_csv(repos_file)
    return users_df, repos_df

def analyze_github_data(users_df, repos_df):
    results = {}
    
    # 1. Top 5 users by followers
    results['q1'] = ','.join(users_df.nlargest(5, 'followers')['login'].tolist())
    
    # 2. 5 earliest registered users
    results['q2'] = ','.join(users_df.sort_values('created_at').head(5)['login'].tolist())
    
    # 3. Top 3 licenses
    license_counts = repos_df['license_name'].value_counts()
    license_counts = license_counts[license_counts.index != '']  # Ignore missing licenses
    results['q3'] = ','.join(license_counts.head(3).index.tolist())
    
    # 4. Most common company
    companies = users_df['company'][users_df['company'] != ''].value_counts()
    results['q4'] = companies.index[0] if not companies.empty else ''
    
    # 5. Most popular language
    lang_counts = repos_df['language'].value_counts()
    results['q5'] = lang_counts.index[0]
    
    # 6. Second most popular language for users who joined after 2020
    recent_users = users_df[pd.to_datetime(users_df['created_at']).dt.year > 2020]['login']
    recent_repos = repos_df[repos_df['login'].isin(recent_users)]
    recent_langs = recent_repos['language'].value_counts()
    results['q6'] = recent_langs.index[1] if len(recent_langs) > 1 else ''
    
    # 7. Language with highest average stars
    avg_stars = repos_df.groupby('language')['stargazers_count'].mean()
    results['q7'] = avg_stars.idxmax()
    
    # 8. Top 5 by leader_strength
    users_df['leader_strength'] = users_df['followers'] / (1 + users_df['following'])
    results['q8'] = ','.join(users_df.nlargest(5, 'leader_strength')['login'].tolist())
    
    # 9. Correlation between followers and public repos
    results['q9'] = f"{users_df['followers'].corr(users_df['public_repos']):.3f}"
    
    # 10. Regression slope of followers on repos
    from scipy import stats
    slope, _, _, _, _ = stats.linregress(users_df['public_repos'], users_df['followers'])
    results['q10'] = f"{slope:.3f}"
    
    # 11. Correlation between projects and wiki
    results['q11'] = f"{repos_df['has_projects'].corr(repos_df['has_wiki']):.3f}"
    
    # 12. Difference in following between hireable and non-hireable
    hireable_following = users_df[users_df['hireable'] == 'True']['following'].mean()
    non_hireable_following = users_df[users_df['hireable'] != 'True']['following'].mean()
    results['q12'] = f"{(hireable_following - non_hireable_following):.3f}"
    
    # 13. Correlation between bio length and followers
    users_df['bio_words'] = users_df['bio'].fillna('').apply(lambda x: len(str(x).split()))
    users_with_bio = users_df[users_df['bio_words'] > 0]
    slope, _, _, _, _ = stats.linregress(users_with_bio['bio_words'], users_with_bio['followers'])
    results['q13'] = f"{slope:.3f}"
    
    # 14. Top 5 weekend repository creators
    repos_df['created_at'] = pd.to_datetime(repos_df['created_at'])
    repos_df['is_weekend'] = repos_df['created_at'].dt.dayofweek.isin([5, 6])
    weekend_creators = repos_df[repos_df['is_weekend']].groupby('login').size()
    results['q14'] = ','.join(weekend_creators.nlargest(5).index.tolist())
    
    # 15. Email sharing difference between hireable and non-hireable
    hireable_email = (users_df[users_df['hireable'] == 'True']['email'] != '').mean()
    non_hireable_email = (users_df[users_df['hireable'] != 'True']['email'] != '').mean()
    results['q15'] = f"{(hireable_email - non_hireable_email):.3f}"
    
    # 16. Most common surname
    def get_surname(name):
        if pd.isna(name) or name.strip() == '':
            return None
        return name.strip().split()[-1]
    
    surnames = users_df['name'].apply(get_surname).value_counts()
    max_count = surnames.max()
    most_common = ','.join(sorted(surnames[surnames == max_count].index.tolist()))
    results['q16'] = most_common
    
    return results

def main():
    # Replace these with your actual file paths
    users_df, repos_df = load_data('tokyo_users_20241031_004140.csv', 'tokyo_repos_20241031_004140.csv')
    results = analyze_github_data(users_df, repos_df)
    
    # Print results
    for q in range(1, 17):
        print(f"Q{q}: {results[f'q{q}']}")

if __name__ == "__main__":
    main()
# Out:
# Q1: dennybritz,wasabeef,dai-shi,rui314,domenic
# Q2: kana,kakutani,mootoh,lhl,walf443
# Q3: MIT License,Apache License 2.0,Other
# Q4: GOOGLE
# Q5: JavaScript
# Q6: JavaScript
# Q7: Assembly
# Q8: blueimp,dai-shi,asahilina,pilcrowonpaper,marcan
# Q9: 0.050
# Q10: 0.271
# Q11: 0.425
# Q12: nan
# Q13: 18.742
# Q14: azu,suzuki-shunsuke,yuiseki,xuwei-k,rhysd
# Q15: nan
# Q16: Kato,Tanaka

# %%
def analyze_hireable_metrics(users_df):
    """
    Analyze metrics related to hireable status
    Returns: (following_diff, email_diff)
    """
    # Convert hireable to boolean, handling different string representations
    users_df['hireable_clean'] = users_df['hireable'].fillna('False')
    users_df['hireable_clean'] = users_df['hireable_clean'].apply(
        lambda x: str(x).lower() in ['true', '1', 't', 'yes']
    )
    
    # Question 12: Following difference
    hireable_following = users_df[users_df['hireable_clean']]['following'].mean()
    non_hireable_following = users_df[~users_df['hireable_clean']]['following'].mean()
    following_diff = hireable_following - non_hireable_following
    
    # Question 15: Email sharing difference
    users_df['has_email'] = users_df['email'].notna() & (users_df['email'] != '')
    hireable_email_rate = users_df[users_df['hireable_clean']]['has_email'].mean()
    non_hireable_email_rate = users_df[~users_df['hireable_clean']]['has_email'].mean()
    email_diff = hireable_email_rate - non_hireable_email_rate
    
    # Print debug information
    print("\nDebug Information:")
    print(f"Total users: {len(users_df)}")
    print(f"Hireable users: {users_df['hireable_clean'].sum()}")
    print(f"Non-hireable users: {(~users_df['hireable_clean']).sum()}")
    print(f"Hireable following avg: {hireable_following:.2f}")
    print(f"Non-hireable following avg: {non_hireable_following:.2f}")
    print(f"Hireable email rate: {hireable_email_rate:.2f}")
    print(f"Non-hireable email rate: {non_hireable_email_rate:.2f}")
    
    return following_diff, email_diff

# Example usage:
import pandas as pd

# Load the data
users_df = pd.read_csv('tokyo_users_20241031_004140.csv')

# Calculate the metrics
following_diff, email_diff = analyze_hireable_metrics(users_df)

print(f"\nQuestion 12 - Following difference: {following_diff:.3f}")
print(f"Question 15 - Email sharing difference: {email_diff:.3f}")
# Out:
# Debug Information:
# Total users: 542
# Hireable users: 180
# Non-hireable users: 362
# Hireable following avg: 182.14
# Non-hireable following avg: 260.63
# Hireable email rate: 0.66
# Non-hireable email rate: 0.53
#
# Question 12 - Following difference: -78.491
# Question 15 - Email sharing difference: 0.131
